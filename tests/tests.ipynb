# %%
import numpy as np
import matplotlib.pyplot as plt
from vast_mw import vast_mw
from astropy.coordinates import SkyCoord
from astropy import units as u
from astropy.time import Time
import warnings

# %%
#Define a source
source = SkyCoord("11h05m21.52536s +43d31m34.9932s", obstime="2023-12-21 21:07:40", frame="icrs")

# %%
#Check Gaia via api
results = vast_mw.check_gaia(source, radius=46*u.arcsec)

# %%
#Print results
print(results)
# Out:
# {'Gaia DR3 778947814402602752': {'coords': <SkyCoord (ICRS): (ra, dec, distance) in (deg, deg, kpc)
#     (166.34205974, 43.53094856, 0.00490466)
#  (pm_ra_cosdec, pm_dec, radial_velocity) in (mas / yr, mas / yr, km / s)
#     (-4406.46917883, 938.52662669, 2.10215745e-15)>, 'separation': <Quantity 37.5366666 arcsec>}, 'Gaia DR3 778947608243864320': {'coords': <SkyCoord (ICRS): (ra, dec, distance) in (deg, deg, kpc)
#     (166.35208968, 43.52590762, 0.00490599)
#  (pm_ra_cosdec, pm_dec, radial_velocity) in (mas / yr, mas / yr, km / s)
#     (-4339.84957844, 960.69613063, -4.59183322e-15)>, 'separation': <Quantity 6.33624331 arcsec>}}

# %%
#Create region file using api
vast_mw.create_regfile(results, radius = 15, filename="sample_name")

# %%
#Get CASDA results (returns astropy table)
casda_results = vast_mw.check_casda(source, radius=3600*u.arcsec)

# %%
#Print CASDA results
print(casda_results)
# Out:
#    obs_id         t_min        ...     separation
#                     d          ...       arcsec
# ----------- ------------------ ... ------------------
# ASKAP-20164  59203.93193518519 ... 10832.734059837467
# ASKAP-20593  59214.88593055555 ... 11329.145901685533
# ASKAP-22674  59253.71318171296 ... 16458.107613430497
# ASKAP-22675 59253.727005787034 ... 12195.399119831023
# ASKAP-25471  59304.56871064815 ... 16923.229272161196
# ASKAP-25473  59304.59600347222 ... 12309.451703696777
# ASKAP-34689  59572.88975578704 ... 16816.514158173293
# ASKAP-34690 59572.901390046296 ...  11301.87813044394
# ASKAP-34691 59572.915214120374 ... 10495.852633850724
#         ...                ... ...                ...
# ASKAP-57652  60327.78642824074 ... 16801.005800345378
# ASKAP-57653 60327.802076388885 ... 12350.643447576826
# ASKAP-60169  60387.66301967593 ... 10506.041369923203
# ASKAP-66381  60589.09230787037 ... 16800.614823166114
# ASKAP-66382  60589.10463425926 ... 12348.070559858716
# ASKAP-66383  60589.11753587963 ... 11323.131589433973
# ASKAP-66801  60602.06451388889 ... 10505.079977764206
# ASKAP-69256  60657.85944097222 ...    16677.979121841
# ASKAP-69257  60657.87061574074 ... 11143.937739611221
# ASKAP-69258  60657.88178935185 ... 12478.646950384596
# Length = 26 rows

# %%
#Convert CASDA results to dictionary via api
casda_dict = vast_mw.table_to_dict(casda_results)

# %%
#Write ds9 reg file
vast_mw.create_regfile(casda_dict, radius=15, filename="casda_sample_name")

# %%
#Command-line usage examples (uncomment to run)
#!check_all -c "11h05m21.52536s,+43d31m34.9932s" -t "2023-12-21 21:07:40" --radius=45 --reg -vv
# Out:
# Checking Gaia
# INFO    : For source at '11h05m21.53s, +43d31m35.0s' = '166.340d, +43.526d', found 2 Gaia matches within 45.0 arcsec
# VAST J1105.3+4332	Gaia DR3 778947608243864320:  6.3 arcsec
# VAST J1105.3+4332	Gaia DR3 778947814402602752: 37.5 arcsec
# INFO    : Wrote ds9 region file VAST_J1105.3+4332_check_gaia.reg
# Checking Simbad
# WARNING : For source at '11h05m21.53s, +43d31m35.0s' = '166.340d, +43.526d', found 0 Simbad matches within 45.0 arcsec
# Checking Pulsar Survey Scraper
# WARNING : For source at '11h05m21.53s, +43d31m35.0s' = '166.340d, +43.526d', found 0 Pulsar Survey Scraper matches within 45.0 arcsec
# Checking ATNF Pulsar Catalog
# WARNING : For source at '11h05m21.53s, +43d31m35.0s' = '166.340d, +43.526d', found 0 ATNF Pulsar Catalog matches within 45.0 arcsec
# Checking Planets
# WARNING: NonRotationTransformationWarning: transforming other coordinates from <ICRS Frame> to <GCRS Frame (obstime=2023-12-21 21:07:40.000, obsgeoloc=(-5472669.58475607, 1623335.17937899, -2836444.93322879) m, obsgeovel=(-118.38189911, -398.59307003, 0.2872842) m / s)>. Angular separation can depend on the direction of the transformation. [astropy.coordinates.baseframe]
# WARNING : For source at '11h05m21.53s, +43d31m35.0s' = '166.340d, +43.526d', found 0 Planets matches within 45.0 arcsec
# Checking TGSS
# WARNING : For source at '11h05m21.53s, +43d31m35.0s' = '166.340d, +43.526d', found 0 TGSS matches within 45.0 arcsec
# Checking FIRST
# WARNING : For source at '11h05m21.53s, +43d31m35.0s' = '166.340d, +43.526d', found 0 FIRST matches within 45.0 arcsec
# Checking NVSS
# WARNING : For source at '11h05m21.53s, +43d31m35.0s' = '166.340d, +43.526d', found 0 NVSS matches within 45.0 arcsec
# Checking Million Quasar
# WARNING : For source at '11h05m21.53s, +43d31m35.0s' = '166.340d, +43.526d', found 0 Million Quasar matches within 45.0 arcsec
# Checking WISEAGN
# WARNING : For source at '11h05m21.53s, +43d31m35.0s' = '166.340d, +43.526d', found 0 WISEAGN matches within 45.0 arcsec
# Checking Large Quasar Astrometric Catalog
# WARNING : For source at '11h05m21.53s, +43d31m35.0s' = '166.340d, +43.526d', found 0 Large Quasar Astrometric Catalog matches within 45.0 arcsec
# Checking SDSS Quasar
# WARNING : For source at '11h05m21.53s, +43d31m35.0s' = '166.340d, +43.526d', found 0 SDSS Quasar matches within 45.0 arcsec
# Checking VLASS
# INFO    : For source at '11h05m21.53s, +43d31m35.0s' = '166.340d, +43.526d', found 2 VLASS matches within 45.0 arcsec
# VAST J1105.3+4332	VLASS1QLCIR J110523.23+433137.2: 18.7 arcsec
# VAST J1105.3+4332	VLASS1QLCIR J110523.24+433137.1: 18.8 arcsec
# INFO    : Wrote ds9 region file VAST_J1105.3+4332_check_vlass.reg

# %%
#!check_all -c "11h05m21.52536s,+43d31m34.9932s" -t "2023-12-21 21:07:40" --radius=45 --reg -vv > log.txt 2>&1
